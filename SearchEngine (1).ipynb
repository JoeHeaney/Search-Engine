# %%
import pandas as pd
from difflib import get_close_matches

def load_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None

def search_data(data_frame, query):
    perfect_matches = data_frame[data_frame['names'].str.contains(query, case=False) | data_frame['authors'].str.contains(query, case=False)]

    if not perfect_matches.empty:
        return perfect_matches
    else:
        names = data_frame['names'].tolist() + data_frame['authors'].tolist()
        closest_matches = get_close_matches(query, names, n=3, cutoff=0.6)

        print(f"No perfect match found. Closest matches: {', '.join(closest_matches)}")
        return pd.DataFrame()

def main():
    file_path = 'minecraftdata1.csv'

    data_frame = load_csv(file_path)

    if data_frame is not None:
        while True:
            search_query = input("Enter a name or author to search (type 'exit' to quit): ")

            if search_query.lower() == 'exit':
                break

            search_results = search_data(data_frame, search_query)

            if not search_results.empty:
                print("Search Results:")
                print(search_results)
            else:
                print("No results found.")

if __name__ == "__main__":
    main()
# Out:
# Enter a name or author to search (type 'exit' to quit): diamond
# Search Results:
#                                              names           authors  \
# 299                                       SkyGuide      DeDiamondPro
# 389                                     Resourcify      DeDiamondPro
# 2792                               Diamond Economy          IAmSneak
# 3353                           Diamond Chest Shops          IAmSneak
# 3429                                  Simple Trims        DiamondDev
# 4065                                        HyCord      DeDiamondPro
# 4173                                 Custom Hearts        Diamond_DP
# 4322                          Diamond In The Rough       digitalpear
# 4436                                Hazard Diamond            acikek
# 4525                            Extensive Diamonds          SirJain0
# 4588   Iron to Diamond Tools Upgrades [PurpurPack]          Rhythmic
# 4631   Iron to Diamond Armor Upgrades [PurpurPack]          Rhythmic
# 4638                                Diamond Ingots         zanderman
# 4824                               Diamond Nuggets           SamDev7
# 5038                                      Enderism        DiamondDev
# 5249                         Diamond Auction House          IAmSneak
# 5391                                      ChatShot      DeDiamondPro
# 5467                     Larger Ore Veins: Diamond  CodingLegend0100
# 6062                                    OVERLOADED        DiamondDev
# 6127                               Diamond Upgrade         paul90317
# 6199                                    Sharp Tone        DiamondDev
# 6625                                  Easy Diamond       BlackWolf00
# 7039                                 Diamond Rails         arthomnix
# 7201                  Ores Above Diamonds (Fabric)               Dvi
# 7447                                 Diamond Glass          kreezxil
# 7984                            Upgrade Structures        Diamond_DP
# 8610                     Coal burning into diamond         bambooawu
# 8990                       Spartans Above Diamonds    Vetpetmon-Labs
# 9062                                       Dialabs        DiamondDev
# 9252                               Christmas Tower        Diamond_DP
# 9358                                    i am speed        DiamondDev
# 9655           Super Minigame Entertainment System        DiamondDev
# 10567                                      FrogJam        DiamondDev
# 10659                                    democracy        DiamondDev
# 11324             [Bite Sized Mods] Diamond Ingots            logabe
# 11583                     Diamond Block Compressor        Busituteng
# 11755                              Elemental Races  BlackDiamond2108
# 11807             Cursed Life - The witch's curse!        Diamond_DP
# 12336                       Ultimate diamond sword      allypallypro
# 12611                                  AssistantMC     DiamondGotCat
# 12724                  GameIdiot's Dirt To Diamond         gameidiot
# 12836                        Alex's Diamond Carrot   KingAlextheKing
#
#                                                 descrips  \
# 299                   Client, Adventure, Minigame, Forge
# 389    Client, Management, Utility, Fabric, Forge, Ne...
# 2792                      Server, Utility, Fabric, Forge
# 3353             Server, Economy, Utility, Fabric, Forge
# 3429   Client and server, Cursed, Equipment, Library,...
# 4065                              Client, Utility, Forge
# 4173   Game Mechanics, Magic, Utility, Data Pack, Fab...
# 4322   Client and server, Cursed, Economy, Mobs, Fabr...
# 4436   Client and server, Decoration, Library, Utilit...
# 4525   Client and server, Adventure, Equipment, World...
# 4588   Equipment, Game Mechanics, Utility, Data Pack,...
# 4631   Equipment, Game Mechanics, Utility, Data Pack,...
# 4638   Client and server, Cursed, World Generation, F...
# 4824   Client and server, Cursed, Utility, Fabric, Forge
# 5038   Client and server, Adventure, Equipment, Game ...
# 5249                             Server, Utility, Fabric
# 5391     Client, Utility, Fabric, Forge, NeoForge, Quilt
# 5467   World Generation, Data Pack, Fabric, Forge, Quilt
# 6062   Server, Cursed, Equipment, Utility, Fabric, Quilt
# 6127   Economy, Game Mechanics, Data Pack, Fabric, Fo...
# 6199   Client and server, Adventure, Equipment, Fabri...
# 6625                        Server, Magic, Fabric, Forge
# 7039   Client and server, Cursed, Transportation, Fab...
# 7201   Client and server, Adventure, Equipment, World...
# 7447   Client and server, Decoration, World Generatio...
# 7984   Adventure, Cursed, Utility, Data Pack, Fabric,...
# 8610                        Server, Fabric, Forge, Quilt
# 8990                 Client and server, Equipment, Forge
# 9062   Client and server, Equipment, Game Mechanics, ...
# 9252   Equipment, Food, Utility, Data Pack, Fabric, F...
# 9358            Client and server, Cursed, Fabric, Quilt
# 9655          Client and server, Minigame, Fabric, Quilt
# 10567                          Client and server, Fabric
# 10659  Client and server, Cursed, Game Mechanics, Soc...
# 11324              Client, Equipment, Technology, Fabric
# 11583      Client and server, Decoration, Utility, Forge
# 11755                           Client and server, Forge
# 11807  Adventure, Cursed, Magic, Data Pack, Fabric, F...
# 12336                           Client and server, Forge
# 12611         Client and server, Mobs, Technology, Forge
# 12724          Client and server, Cursed, Utility, Forge
# 12836                     Client and server, Food, Forge
#
#                                               paragraphs
# 299    A mod that aims to improve the Hypixel SkyBloc...
# 389    In-game resource pack, data pack and shader br...
# 2792             Simple diamond-based economy for fabric
# 3353             Chest shops for the Diamond Economy mod
# 3429   allow for the dynamic creation of armor trim m...
# 4065                 Discord integration mod for Hypixel
# 4173   This datapack adds 10 custom hearts with custo...
# 4322                      Renewable diamonds in the end.
# 4436   Implements the NFPA 704 and GHS identification...
# 4525                    Adds more diamonds to Minecraft!
# 4588   Allows iron tools to be upgraded to diamond on...
# 4631   Allows upgrading iron armor to diamond in a sm...
# 4638                  The harder way to obtain diamonds!
# 4824   There's iron and gold nuggets, why not diamond...
# 5038            End and Endgame Expansion and Tweaks mod
# 5249             Auction House Addon for Diamond Economy
# 5391   Copy chat messages as text or a nice transpare...
# 5467   The diamond edition of Larger Ore Veins makes ...
# 6062   bypass enchantment level limits with ease; "ov...
# 6127                 Upgrade your items to diamond ones.
# 6199                         An Instument, and a Weapon?
# 6625                       An easy way to craft diamonds
# 7039   Make minecarts useful late game with 3 new fas...
# 7201   The Ores Above Diamonds Mod adds the Amethyst ...
# 7447               Glass with the attributes of bedrock.
# 7984   This datapack allow you to upgrade vanilla str...
# 8610   This is a lightweight survival aid mod,This mo...
# 8990   Addon for Spartan's Weaponry that adds support...
# 9062        Random Kitchensink Additions, that's the mod
# 9252   A datapack adding 12 new CUSTOM CHRISTMAS ITEM...
# 9358                 I constantly suffer from high speed
# 9655                            A Minecraft Minigame Mod
# 10567                              they do be jammin tho
# 10659     my allegiance is to the republic, to democracy
# 11324  Have you ever felt like there just weren't eno...
# 11583     This mod can compress a lot of diamond blocks.
# 11755  Mod that adds 6 different races to your expiri...
# 11807  You were cursed by a witch! The curse constant...
# 12336                     craft a ultimate diamond sword
# 12611                            Assistant for Minecraft
# 12724  This mod aims to implement ShyGuy_Deku's and m...
# 12836             Adds diamond carrots because i'm bored
